# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practise').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/06/05 12:25:10 WARN Utils: Your hostname, SAJINs-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.16 instead (on interface en0)
# 26/06/05 12:25:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/05 12:25:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.16:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
os.getcwd()
# Out:
# '/Users/sajina.k/Learning Pyspark'

# %%
spark.read.csv('employee_dataset.csv',header = True,inferSchema=True).show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh|NULL|      NULL|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|      NULL|   NULL|
# +---------+----+----------+-------+

# %%
df_pyspark = spark.read.csv('employee_dataset.csv',header = True,inferSchema=True)

# %%
df_pyspark
# Out:
# DataFrame[Name: string, Age: double, Experience: double, Salary: double]

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh|NULL|      NULL|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|      NULL|   NULL|
# +---------+----+----------+-------+

# %%
# drop the column
df_pyspark.drop('Name').show()
# Out:
# +----+----------+-------+
# | Age|Experience| Salary|
# +----+----------+-------+
# |31.0|      10.0|30000.0|
# |30.0|       8.0|25000.0|
# |29.0|       4.0|20000.0|
# |24.0|       3.0|20000.0|
# |21.0|       1.0|15000.0|
# |23.0|       2.0|18000.0|
# |NULL|      NULL|40000.0|
# |34.0|      10.0|38000.0|
# |36.0|      NULL|   NULL|
# +----+----------+-------+

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh|NULL|      NULL|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|      NULL|   NULL|
# +---------+----+----------+-------+

# %%
df_pyspark.na.drop().show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# +---------+----+----------+-------+

# %%
# any  == how
df_pyspark.na.drop(how = 'all').show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh|NULL|      NULL|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|      NULL|   NULL|
# +---------+----+----------+-------+

# %%
df_pyspark.na.drop(how = 'any').show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# +---------+----+----------+-------+

# %%
# threshold
df_pyspark.na.drop(how = 'any',thresh = 2).show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh|NULL|      NULL|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# +---------+----+----------+-------+

# %%
df_pyspark.na.drop(how = 'any',thresh = 3).show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |     NULL|34.0|      10.0|38000.0|
# +---------+----+----------+-------+

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh|NULL|      NULL|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|      NULL|   NULL|
# +---------+----+----------+-------+

# %%
df_pyspark.na.drop(how = 'any',thresh = 4).show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# +---------+----+----------+-------+

# %%
#subset 
df_pyspark.na.drop(how = 'any',subset = ['Experience']).show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |     NULL|34.0|      10.0|38000.0|
# +---------+----+----------+-------+

# %%
df_pyspark.na.drop(how = 'any',subset = ['Experience','Name']).show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# +---------+----+----------+-------+

# %%
# Filling the missing values

df_pyspark.na.fill('Missing Values').show()
# Out:
# +--------------+----+----------+-------+
# |          Name| Age|Experience| Salary|
# +--------------+----+----------+-------+
# |         Krish|31.0|      10.0|30000.0|
# |     Sudhanshu|30.0|       8.0|25000.0|
# |         Sunny|29.0|       4.0|20000.0|
# |          Paul|24.0|       3.0|20000.0|
# |        Harsha|21.0|       1.0|15000.0|
# |       Shubham|23.0|       2.0|18000.0|
# |        Mahesh|NULL|      NULL|40000.0|
# |Missing Values|34.0|      10.0|38000.0|
# |Missing Values|36.0|      NULL|   NULL|
# +--------------+----+----------+-------+

# %%
df_pyspark.na.fill(0).show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh| 0.0|       0.0|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|       0.0|    0.0|
# +---------+----+----------+-------+

# %%
df_pyspark.na.fill(0,'Salary').show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh|NULL|      NULL|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|      NULL|    0.0|
# +---------+----+----------+-------+

# %%
df_pyspark.na.fill(0,['Age','Experience','Salary']).show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh| 0.0|       0.0|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|       0.0|    0.0|
# +---------+----+----------+-------+

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+-------+
# |     Name| Age|Experience| Salary|
# +---------+----+----------+-------+
# |    Krish|31.0|      10.0|30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|
# |    Sunny|29.0|       4.0|20000.0|
# |     Paul|24.0|       3.0|20000.0|
# |   Harsha|21.0|       1.0|15000.0|
# |  Shubham|23.0|       2.0|18000.0|
# |   Mahesh|NULL|      NULL|40000.0|
# |     NULL|34.0|      10.0|38000.0|
# |     NULL|36.0|      NULL|   NULL|
# +---------+----+----------+-------+

# %%
from pyspark.ml.feature import Imputer

imputer = Imputer(
    inputCols = ['age','Experience','Salary'],
    outputCols = ["{}_imputed".format(c) for c in ['Age','Experience','Salary']]
).setStrategy('mean')

# %%
imputer.fit(df_pyspark).transform(df_pyspark).show()
# Out:
# +---------+----+----------+-------+-----------+------------------+--------------+
# |     Name| Age|Experience| Salary|Age_imputed|Experience_imputed|Salary_imputed|
# +---------+----+----------+-------+-----------+------------------+--------------+
# |    Krish|31.0|      10.0|30000.0|       31.0|              10.0|       30000.0|
# |Sudhanshu|30.0|       8.0|25000.0|       30.0|               8.0|       25000.0|
# |    Sunny|29.0|       4.0|20000.0|       29.0|               4.0|       20000.0|
# |     Paul|24.0|       3.0|20000.0|       24.0|               3.0|       20000.0|
# |   Harsha|21.0|       1.0|15000.0|       21.0|               1.0|       15000.0|
# |  Shubham|23.0|       2.0|18000.0|       23.0|               2.0|       18000.0|
# |   Mahesh|NULL|      NULL|40000.0|       28.5| 5.428571428571429|       40000.0|
# |     NULL|34.0|      10.0|38000.0|       34.0|              10.0|       38000.0|
# ...
