# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 MB 22.0 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... one
# ...
#   DEPRECATION: Building 'pyspark' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pyspark'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# done
#   Created wheel for pyspark: filename=pyspark-4.1.1-py2.py3-none-any.whl size=456008641 sha256=335046f9e2f4100136a735efd053873e5be73aa23cfb32291769464d9dcc5d3c
#   Stored in directory: /Users/sajin/Library/Caches/pip/wheels/73/4f/41/4e171cb4fbdafa33a7b8e1d7e8b19e04e0c075aad98572acec
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
import pandas as pd

# %%
data = pd.read_csv("student_performance_grade.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  8000 non-null   object
#  1   Age                         8000 non-null   int64
#  2   Gender                      8000 non-null   object
#  3   Hours_Studied               8000 non-null   float64
#  4   Attendance                  8000 non-null   float64
#  5   Sleep_Hours                 8000 non-null   float64
#  6   Stress_Level                8000 non-null   float64
#  7   Screen_Time                 8000 non-null   float64
#  8   Previous_GPA                8000 non-null   float64
#  9   Part_Time_Job               8000 non-null   object
#  10  Study_Method                8000 non-null   object
#  11  Diet_Quality                8000 non-null   object
#  12  Internet_Quality            8000 non-null   object
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practise').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/21 17:25:13 WARN Utils: Your hostname, SAJINs-MacBook-Air-3.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.8 instead (on interface en0)
# 26/05/21 17:25:13 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/21 17:25:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.8:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv('student_performance_grade.csv')

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string, _c6: string, _c7: string, _c8: string, _c9: string, _c10: string, _c11: string, _c12: string, _c13: string, _c14: string, _c15: string, _c16: string, _c17: string]

# %%
df_pyspark.show()
# Out:
# +----------+---+----------+-------------+----------+-----------+------------+-----------+------------+-------------+------------+------------+----------------+---------------+--------------------+-------------------+------------------+-----+
# |       _c0|_c1|       _c2|          _c3|       _c4|        _c5|         _c6|        _c7|         _c8|          _c9|        _c10|        _c11|            _c12|           _c13|                _c14|               _c15|              _c16| _c17|
# +----------+---+----------+-------------+----------+-----------+------------+-----------+------------+-------------+------------+------------+----------------+---------------+--------------------+-------------------+------------------+-----+
# |Student_ID|Age|    Gender|Hours_Studied|Attendance|Sleep_Hours|Stress_Level|Screen_Time|Previous_GPA|Part_Time_Job|Study_Method|Diet_Quality|Internet_Quality|Extracurricular|Tutoring_Sessions...|Family_Income_Level|Exam_Anxiety_Score|Grade|
# ...

# %%
no = spark.read.option('header','true').csv('student_performance_grade.csv')

# %%
mo = spark.read.option('header','true').csv('student_performance_grade.csv').show()
# Out:
# +----------+---+----------+-------------+----------+-----------+------------+-----------+------------+-------------+------------+------------+----------------+---------------+--------------------------+-------------------+------------------+-----+
# |Student_ID|Age|    Gender|Hours_Studied|Attendance|Sleep_Hours|Stress_Level|Screen_Time|Previous_GPA|Part_Time_Job|Study_Method|Diet_Quality|Internet_Quality|Extracurricular|Tutoring_Sessions_Per_Week|Family_Income_Level|Exam_Anxiety_Score|Grade|
# +----------+---+----------+-------------+----------+-----------+------------+-----------+------------+-------------+------------+------------+----------------+---------------+--------------------------+-------------------+------------------+-----+
# |  STU00001| 17|    Female|          8.2|        80|        7.3|         2.3|        3.2|        3.07|           No|      Online|     Average|         Average|            Yes|                         3|               High|               1.8|    A|
# ...

# %%
type(mo)
# Out:
# NoneType

# %%
type(no)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
no.head(3)
# Out:
# [Row(Student_ID='STU00001', Age='17', Gender='Female', Hours_Studied='8.2', Attendance='80', Sleep_Hours='7.3', Stress_Level='2.3', Screen_Time='3.2', Previous_GPA='3.07', Part_Time_Job='No', Study_Method='Online', Diet_Quality='Average', Internet_Quality='Average', Extracurricular='Yes', Tutoring_Sessions_Per_Week='3', Family_Income_Level='High', Exam_Anxiety_Score='1.8', Grade='A'),
#  Row(Student_ID='STU00002', Age='22', Gender='Male', Hours_Studied='4.07', Attendance='69.2', Sleep_Hours='7.9', Stress_Level='3.6', Screen_Time='0.5', Previous_GPA='2.66', Part_Time_Job='Yes', Study_Method='Offline', Diet_Quality='Average', Internet_Quality='Good', Extracurricular='No', Tutoring_Sessions_Per_Week='2', Family_Income_Level='Middle', Exam_Anxiety_Score='1', Grade='A'),
# ...

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: string (nullable = true)
#  |-- _c14: string (nullable = true)
#  |-- _c15: string (nullable = true)
#  |-- _c16: string (nullable = true)
#  |-- _c17: string (nullable = true)
