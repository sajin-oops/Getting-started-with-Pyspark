# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Dataframe').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/22 19:28:21 WARN Utils: Your hostname, SAJINs-MacBook-Air-3.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.22 instead (on interface en0)
# 26/05/22 19:28:21 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/22 19:28:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.22:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#Lets read the dataset using pyspark

# %%
spark.read.option('header','true').csv('employee_data.csv')
# Out:
# DataFrame[Name: string, Age: string, Experience (Years): string]

# %%
df_pyspark = spark.read.option('header','true').csv('employee_data.csv').show()
# Out:
# +------------+---+------------------+
# |        Name|Age|Experience (Years)|
# +------------+---+------------------+
# |  Arun Kumar| 25|                 2|
# |Priya Sharma| 28|                 4|
# | Rahul Verma| 30|                 6|
# | Sneha Patel| 27|                 3|
# |Vikram Singh| 35|                10|
# +------------+---+------------------+

# %%
df_pyspark = spark.read.option('header','true').csv('employee_data.csv',inferSchema = True)

# %%
# check the schema

# %%
df_pyspark.printSchema()  # without inferSchema = True, the data type may show wrongly.
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience (Years): integer (nullable = true)

# %%
#Another way of reading csv file

# %%
df_pyspark = spark.read.csv('employee_data.csv',header = 'True',inferSchema = True)
df_pyspark.show()
# Out:
# +------------+---+------------------+
# |        Name|Age|Experience (Years)|
# +------------+---+------------------+
# |  Arun Kumar| 25|                 2|
# |Priya Sharma| 28|                 4|
# | Rahul Verma| 30|                 6|
# | Sneha Patel| 27|                 3|
# |Vikram Singh| 35|                10|
# +------------+---+------------------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience (Years): integer (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# ['Name', 'Age', 'Experience (Years)']

# %%
df_pyspark.head(2)
# Out:
# [Row(Name='Arun Kumar', Age=25, Experience (Years)=2),
#  Row(Name='Priya Sharma', Age=28, Experience (Years)=4)]

# %%
df_pyspark.show()
# Out:
# +------------+---+------------------+
# |        Name|Age|Experience (Years)|
# +------------+---+------------------+
# |  Arun Kumar| 25|                 2|
# |Priya Sharma| 28|                 4|
# | Rahul Verma| 30|                 6|
# | Sneha Patel| 27|                 3|
# |Vikram Singh| 35|                10|
# +------------+---+------------------+

# %%
df_pyspark.select('Name')
# Out:
# DataFrame[Name: string]

# %%
df_pyspark.select('Name').show()
# Out:
# +------------+
# |        Name|
# +------------+
# |  Arun Kumar|
# |Priya Sharma|
# | Rahul Verma|
# | Sneha Patel|
# |Vikram Singh|
# +------------+

# %%
df_pyspark.select(['Name','Experience (Years)']).show()
# Out:
# +------------+------------------+
# |        Name|Experience (Years)|
# +------------+------------------+
# |  Arun Kumar|                 2|
# |Priya Sharma|                 4|
# | Rahul Verma|                 6|
# | Sneha Patel|                 3|
# |Vikram Singh|                10|
# +------------+------------------+

# %%
df_pyspark['Name']
# Out:
# Column<'Name'>

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('Age', 'int'), ('Experience (Years)', 'int')]

# %%
df_pyspark.describe()
# Out:
# DataFrame[summary: string, Name: string, Age: string, Experience (Years): string]

# %%
df_pyspark.describe().show()
# Out:
# +-------+------------+------------------+------------------+
# |summary|        Name|               Age|Experience (Years)|
# +-------+------------+------------------+------------------+
# |  count|           5|                 5|                 5|
# |   mean|        NULL|              29.0|               5.0|
# | stddev|        NULL|3.8078865529319543|3.1622776601683795|
# |    min|  Arun Kumar|                25|                 2|
# |    max|Vikram Singh|                35|                10|
# +-------+------------+------------------+------------------+

# %%
# adding columns in data frame

# %%
df_pyspark.withColumn('Experience After 2 years', df_pyspark['Experience (Years)']+2).show()
# Out:
# +------------+---+------------------+------------------------+
# |        Name|Age|Experience (Years)|Experience After 2 years|
# +------------+---+------------------+------------------------+
# |  Arun Kumar| 25|                 2|                       4|
# |Priya Sharma| 28|                 4|                       6|
# | Rahul Verma| 30|                 6|                       8|
# | Sneha Patel| 27|                 3|                       5|
# |Vikram Singh| 35|                10|                      12|
# +------------+---+------------------+------------------------+

# %%
df_pyspark.show()
# Out:
# +------------+---+------------------+
# |        Name|Age|Experience (Years)|
# +------------+---+------------------+
# |  Arun Kumar| 25|                 2|
# |Priya Sharma| 28|                 4|
# | Rahul Verma| 30|                 6|
# | Sneha Patel| 27|                 3|
# |Vikram Singh| 35|                10|
# +------------+---+------------------+

# %%
df_pyspark = df_pyspark.withColumn('Experience After 2 years', df_pyspark['Experience (Years)']+2)

# %%
df_pyspark.show()
# Out:
# +------------+---+------------------+------------------------+
# |        Name|Age|Experience (Years)|Experience After 2 years|
# +------------+---+------------------+------------------------+
# |  Arun Kumar| 25|                 2|                       4|
# |Priya Sharma| 28|                 4|                       6|
# | Rahul Verma| 30|                 6|                       8|
# | Sneha Patel| 27|                 3|                       5|
# |Vikram Singh| 35|                10|                      12|
# +------------+---+------------------+------------------------+

# %%
# Drop the columns

# %%
df_pyspark = df_pyspark.drop('Experience After 2 years').show()
# Out:
# +------------+---+------------------+
# |        Name|Age|Experience (Years)|
# +------------+---+------------------+
# |  Arun Kumar| 25|                 2|
# |Priya Sharma| 28|                 4|
# | Rahul Verma| 30|                 6|
# | Sneha Patel| 27|                 3|
# |Vikram Singh| 35|                10|
# +------------+---+------------------+
